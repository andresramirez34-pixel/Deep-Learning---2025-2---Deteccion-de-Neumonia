# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.utils import class_weight
import numpy as np
import os

# Check for GPU
num_gpus = len(tf.config.list_physical_devices('GPU'))
print(f"Num GPUs Available: {num_gpus}")

# --- NEW: Distribution Strategy ---
if num_gpus > 1:
    strategy = tf.distribute.MirroredStrategy()
    print('Distribution strategy: MirroredStrategy (using multiple GPUs)')
else:
    strategy = tf.distribute.OneDeviceStrategy(device="/gpu:0") # Or "/cpu:0" if no GPU
    print('Distribution strategy: OneDeviceStrategy (using a single GPU or CPU)')
# ---------------------------------
# Out:
# 2025-12-03 03:55:51.325747: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764734151.541402      20 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764734151.603527      20 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# Num GPUs Available: 2
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Distribution strategy: MirroredStrategy (using multiple GPUs)
# I0000 00:00:1764734169.274406      20 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1764734169.275066      20 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
# Define parameters
IMG_SIZE = (299, 299)

# Since we have 2 GPUs, we can double the batch size for better efficiency.
BATCH_SIZE_PER_REPLICA = 64
BATCH_SIZE = BATCH_SIZE_PER_REPLICA * num_gpus
LR = 0.001
EPOCHS = 100 # MAX

print(f"Using a global batch size of: {BATCH_SIZE}")

# Kaggle dataset paths
train_dir = '/kaggle/input/chest-xray-pneumonia/chest_xray/train'
test_dir = '/kaggle/input/chest-xray-pneumonia/chest_xray/test'
val_dir = '/kaggle/input/chest-xray-pneumonia/chest_xray/val'

# 1. Define Generators (No change here)
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=15,
    zoom_range=0.2,
    horizontal_flip=True
)
val_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
test_datagen = ImageDataGenerator(rescale=1./255)

# 2. Create Directory Iterators
train_gen = train_datagen.flow_from_directory(
    '/kaggle/input/chest-xray-pneumonia/chest_xray/train',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

val_gen = val_datagen.flow_from_directory(
    '/kaggle/input/chest-xray-pneumonia/chest_xray/train',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

# 2.5. Create the Test Directory Iterator (The Missing Piece)
# Note: Use shuffle=False for reproducible evaluation
test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# 3. CONVERT TO tf.data.Dataset (The Fix!)
# This wrapper handles the multi-GPU splitting logic safely

def tf_data_generator(generator, input_shape):
    num_classes = generator.num_classes
    dataset = tf.data.Dataset.from_generator(
        lambda: generator,
        output_types=(tf.float32, tf.float32),
        output_shapes=([None, *input_shape], [None, num_classes])
    )
    return dataset

# Wrap Train Set
train_dataset = tf_data_generator(train_gen, (299, 299, 3))
train_dataset = train_dataset.unbatch().batch(BATCH_SIZE, drop_remainder=True)
train_dataset = train_dataset.repeat() # Loops indefinitely
train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)

# Wrap Validation Set
val_dataset = tf_data_generator(val_gen, (299, 299, 3))
val_dataset = val_dataset.unbatch().batch(BATCH_SIZE, drop_remainder=True)
val_dataset = val_dataset.repeat()
val_dataset = val_dataset.prefetch(tf.data.AUTOTUNE)

# Calculate Steps per Epoch (Since we use .repeat(), we must specify steps manually)
steps_per_epoch = train_gen.samples // BATCH_SIZE
validation_steps = val_gen.samples // BATCH_SIZE
# Calculate steps to cover the whole test set
test_steps = int(np.ceil(test_gen.samples / BATCH_SIZE))

print(f"Steps per epoch: {steps_per_epoch}")
print(f"Validation steps: {validation_steps}")
print(f"Test steps: {test_steps}")

# 4. Class Weights (Recalculate)
train_classes = train_gen.classes
class_weights_vals = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_classes),
    y=train_classes
)
class_weights_dict = dict(enumerate(class_weights_vals))
# Out:
# Using a global batch size of: 128
# Found 4173 images belonging to 2 classes.
# Found 1043 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Steps per epoch: 32
# Validation steps: 8
# Test steps: 5

# %%
# Wrap Model Definition and Compilation in the strategy scope
with strategy.scope():
    # 1. Load Inception V3 with ImageNet weights, excluding the top layers
    base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

    # 2. Freeze the convolutional layers
    for layer in base_model.layers:
        layer.trainable = False

    # 3. Add the new classification layers
    x = base_model.output
    x = GlobalAveragePooling2D()(x) # "Bottleneck" features
    x = Dropout(0.5)(x)  # Drops 50% of connections to prevent overfitting
    predictions = Dense(train_gen.num_classes, activation='softmax')(x)

    # Create the final model
    model = Model(inputs=base_model.input, outputs=predictions)

    # Compile the model
    # The optimizer is now initialized within the strategy scope
    model.compile(optimizer=Adam(learning_rate=LR),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# --- Callbacks ---
# 1. Save the best model (Persist progress)
checkpoint_callback = ModelCheckpoint(
    filepath='/kaggle/working/InceptionV3_pneumonia_best.weights.h5',
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=1
)

# 2. Stop early if no improvement (Replicates paper's behavior [cite: 332])
early_stopping_callback = EarlyStopping(
    monitor='val_accuracy',   # Watch validation accuracy
    patience=10,              # Stop if it doesn't improve for 10 epochs
    restore_best_weights=True # Go back to the best version automatically
)

# Put all callbacks into a list
callbacks_list = [checkpoint_callback, early_stopping_callback]

# %%
# Train the model
print("Starting training on multiple GPUs...")
history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_dataset,
    validation_steps=validation_steps,
    class_weight=class_weights_dict,
    callbacks=callbacks_list
)
# Out:
# Starting training on multiple GPUs...
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Epoch 1/100
# INFO:tensorflow:Collective all_reduce tensors: 1 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 1 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 2 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 1 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 1 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# I0000 00:00:1764734199.264872      60 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1764734199.264882      63 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.5525 - loss: 0.7850INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Collective all_reduce tensors: 1 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 1 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 1 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 1 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
#
# Epoch 1: val_accuracy improved from -inf to 0.81688, saving model to /kaggle/working/InceptionV3_pneumonia_best.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 173s 5s/step - accuracy: 0.5526 - loss: 0.7849 - val_accuracy: 0.8169 - val_loss: 0.3942
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8660 - loss: 0.2991INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Epoch 2: val_accuracy improved from 0.81688 to 0.81725, saving model to /kaggle/working/InceptionV3_pneumonia_best.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 100s 3s/step - accuracy: 0.8660 - loss: 0.2992 - val_accuracy: 0.8172 - val_loss: 0.3830
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8936 - loss: 0.2649INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Epoch 3: val_accuracy improved from 0.81725 to 0.85190, saving model to /kaggle/working/InceptionV3_pneumonia_best.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.8936 - loss: 0.2648 - val_accuracy: 0.8519 - val_loss: 0.3440
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8486 - loss: 0.2593INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Epoch 4: val_accuracy did not improve from 0.85190
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 110s 4s/step - accuracy: 0.8487 - loss: 0.2593 - val_accuracy: 0.8427 - val_loss: 0.3550
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9095 - loss: 0.2304
# Epoch 5: val_accuracy improved from 0.85190 to 0.89188, saving model to /kaggle/working/InceptionV3_pneumonia_best.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 112s 4s/step - accuracy: 0.9095 - loss: 0.2304 - val_accuracy: 0.8919 - val_loss: 0.2821
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9151 - loss: 0.1805
# Epoch 6: val_accuracy improved from 0.89188 to 0.91474, saving model to /kaggle/working/InceptionV3_pneumonia_best.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 112s 4s/step - accuracy: 0.9151 - loss: 0.1805 - val_accuracy: 0.9147 - val_loss: 0.2354
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9165 - loss: 0.2087
# Epoch 7: val_accuracy did not improve from 0.91474
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 111s 4s/step - accuracy: 0.9165 - loss: 0.2087 - val_accuracy: 0.9006 - val_loss: 0.2246
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9191 - loss: 0.1952
# Epoch 8: val_accuracy did not improve from 0.91474
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 109s 4s/step - accuracy: 0.9191 - loss: 0.1952 - val_accuracy: 0.8615 - val_loss: 0.3353
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9161 - loss: 0.1822
# Epoch 9: val_accuracy did not improve from 0.91474
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 113s 4s/step - accuracy: 0.9161 - loss: 0.1823 - val_accuracy: 0.8406 - val_loss: 0.3819
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9233 - loss: 0.1762
# Epoch 10: val_accuracy did not improve from 0.91474
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 109s 4s/step - accuracy: 0.9233 - loss: 0.1763 - val_accuracy: 0.9133 - val_loss: 0.2105
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9278 - loss: 0.1829
# Epoch 11: val_accuracy did not improve from 0.91474
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 109s 4s/step - accuracy: 0.9278 - loss: 0.1828 - val_accuracy: 0.8723 - val_loss: 0.2963
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9178 - loss: 0.1852
# Epoch 12: val_accuracy did not improve from 0.91474
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 113s 4s/step - accuracy: 0.9178 - loss: 0.1853 - val_accuracy: 0.8645 - val_loss: 0.3327
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9267 - loss: 0.1441
# Epoch 13: val_accuracy improved from 0.91474 to 0.91532, saving model to /kaggle/working/InceptionV3_pneumonia_best.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 111s 4s/step - accuracy: 0.9267 - loss: 0.1442 - val_accuracy: 0.9153 - val_loss: 0.2147
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9462 - loss: 0.1392
# Epoch 14: val_accuracy improved from 0.91532 to 0.91945, saving model to /kaggle/working/InceptionV3_pneumonia_best.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9462 - loss: 0.1392 - val_accuracy: 0.9195 - val_loss: 0.1832
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9370 - loss: 0.1881
# Epoch 15: val_accuracy improved from 0.91945 to 0.94148, saving model to /kaggle/working/InceptionV3_pneumonia_best.weights.h5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 111s 4s/step - accuracy: 0.9370 - loss: 0.1880 - val_accuracy: 0.9415 - val_loss: 0.1634
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9182 - loss: 0.2061
# Epoch 16: val_accuracy did not improve from 0.94148
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 108s 3s/step - accuracy: 0.9182 - loss: 0.2061 - val_accuracy: 0.9397 - val_loss: 0.1884
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9536 - loss: 0.1591
# Epoch 17: val_accuracy did not improve from 0.94148
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9536 - loss: 0.1591 - val_accuracy: 0.8965 - val_loss: 0.2734
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9291 - loss: 0.1652
# Epoch 18: val_accuracy did not improve from 0.94148
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 113s 4s/step - accuracy: 0.9291 - loss: 0.1652 - val_accuracy: 0.8681 - val_loss: 0.2970
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9246 - loss: 0.1749
# Epoch 19: val_accuracy did not improve from 0.94148
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.9246 - loss: 0.1749 - val_accuracy: 0.9173 - val_loss: 0.2115
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9259 - loss: 0.2208
# Epoch 20: val_accuracy did not improve from 0.94148
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 112s 4s/step - accuracy: 0.9259 - loss: 0.2208 - val_accuracy: 0.8843 - val_loss: 0.2949
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9224 - loss: 0.1964
# Epoch 21: val_accuracy did not improve from 0.94148
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 113s 4s/step - accuracy: 0.9224 - loss: 0.1964 - val_accuracy: 0.8797 - val_loss: 0.2801
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9028 - loss: 0.2379
# Epoch 22: val_accuracy did not improve from 0.94148
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.9028 - loss: 0.2379 - val_accuracy: 0.8838 - val_loss: 0.2971
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9412 - loss: 0.1735
# Epoch 23: val_accuracy did not improve from 0.94148
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 110s 4s/step - accuracy: 0.9411 - loss: 0.1735 - val_accuracy: 0.9313 - val_loss: 0.1926
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9244 - loss: 0.2470
# Epoch 24: val_accuracy did not improve from 0.94148
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 112s 4s/step - accuracy: 0.9244 - loss: 0.2469 - val_accuracy: 0.8900 - val_loss: 0.3131
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9246 - loss: 0.2078
# Epoch 25: val_accuracy did not improve from 0.94148
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 109s 4s/step - accuracy: 0.9246 - loss: 0.2078 - val_accuracy: 0.8841 - val_loss: 0.2762

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Final Evaluation on Test Set
test_loss, test_acc = model.evaluate(test_gen, steps=test_steps)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc*100:.2f}%")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# INFO:tensorflow:Collective all_reduce tensors: 1 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 1 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 1 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Collective all_reduce tensors: 1 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.7778 - loss: 0.5502
# Test Loss: 0.5028
# Test Accuracy: 79.81%
